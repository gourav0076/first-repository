# %%
import matplotlib.pyplot as plt # matplotlib utilities lies under pyplot submodules
import numpy as np

## draw a line in a diagram from (0,10) to (5,150) 
xpoints = np.array([0, 10])
ypoints = np.array([5, 150])

plt.plot(xpoints,ypoints)
plt.show()

# %% [markdown]
# The plot() function is used to draw points(markers) in a diagram.
# By default plot function draws a line from point to point.
# If we need to plot a line from (1,7) to (8,11) ,we have to pass two arrays [1,7] and [8,11] to the plot function.

# %%
xpoints=np.array([1,6])
ypoints=np.array([5,11])

plt.plot(xpoints,ypoints)
plt.show()

# %%
ypoints=np.array([4,7])

plt.plot(xpoints,ypoints,'o') # if marker not mentioned it will give onlly points
plt.show()

# %%
ypoints=np.array([1,4,7,3])

plt.plot(ypoints,marker='o') # by default it would take xponits as 0,1,2,3
plt.show()

# %% [markdown]
# different types of markers are available
# e.g o,*,",",+,x,"D", "d", ">" etc

# %%
plt.plot(ypoints,marker='D')

# %%
ypoints=np.array([1,4,7,3])

plt.plot(ypoints, 'o:g') # o to depict the circular points , : to depict the dotted lines , g to depict the green colour
plt.show()

# %% [markdown]
# 'r' Red
# 'g' Green
# 'c' Cyan
# 'b' Blue
# 'm' magenta
# 'k' black
# etc
#
#
# "-" Solid Line
# ":" Dotted line
# "-" Dashed Line
# "-." Dashed dotted line

# %%
ypoints=np.array([1,4,7,3])

plt.plot(ypoints,marker='o', ms=20 , mec = 'k') # ms : marker size , mec : markeredgecolour 
plt.show()

# %%
ypoints=np.array([1,4,7,3])

plt.plot(ypoints,'o-.y', ms=20 , mec = 'r') # ms : marker size , mec : markeredgecolour 
plt.show()

# %%
ypoints=np.array([1,4,7,3])

plt.plot(ypoints,'o-.y', ms=20 , mfc = 'r') # ms : marker size , mec : markeredgecolour , mfc : markerfacecolour
plt.show()

# %%
ypoints=np.array([1,4,7,3])

plt.plot(ypoints,'o-.y', ms=20 , mec = 'r', mfc='g') # ms : marker size , mec : markeredgecolour 
plt.show()

# %%
ypoints=np.array([1,4,7,3])

plt.plot(ypoints,'o-.y', ms=20 , mec = 'r' , mfc='#4CEE30') # ms : marker size , mec : markeredgecolour 
plt.show()

# %%
ypoints=np.array([1,4,7,3])

plt.plot(ypoints,'o-.y', ms=20 , mec = '#4CAE40', mfc='hotpink') # ms : marker size , mec : markeredgecolour 
plt.show()

# %%
ypoints=np.array([1,4,7,3])

plt.plot(ypoints, linestyle = 'dotted') # ms : marker size , mec : markeredgecolour 
plt.show()

# %%
ypoints=np.array([1,4,7,3])

plt.plot(ypoints,linestyle = 'dashed') # ms : marker size , mec : markeredgecolour 
plt.show()

# %%
ypoints=np.array([1,4,7,3])

plt.plot(ypoints,linewidth='12.5')
plt.show()

# %%
y1=np.array([3,8,1,10])
y2=np.array([6,2,5,11])

plt.plot(y1)
plt.plot(y2)
plt.show()

# %%
x1=np.array([0,2,4,6])
y1=np.array([3,8,1,10])
x2=np.array([0,5,10,15])
y2=np.array([6,2,7,11])

plt.plot(x1,x2,y1,y2)
plt.show()

# %%
x=np.array([80,90,60,70,30,50])
y=np.array([180,190,160,170,130,150])

plt.plot(x,y)

plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.show()

# %%
# you can use fontdict in xlabel(),ylabel() and title() to set font properties for graph
x=np.array([80,90,60,70,30,50])
y=np.array([180,190,160,170,130,150])

font1 = {'family':'serif','color':'blue','size':20}
font2 = {'family':'calibri','color':'red','size':15}

plt.title("Sports data", fontdict=font1)
plt.xlabel("Average Pulse",fontdict=font1)
plt.ylabel("Calorie Burnage",fontdict=font2)

plt.plot(x,y)
plt.show()

# %%
x=np.array([80,90,60,70,30,50])
y=np.array([180,190,160,170,130,150])


plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.plot(x,y)

plt.grid()
plt.show()

# %%
x=np.array([80,90,60,70,30,50])
y=np.array([180,190,160,170,130,150])


plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.plot(x,y)

plt.grid(color='green', linestyle= '--',linewidth=0.5)
plt.show()

# %%
#plot1
x=np.array([0,1,2,3])
y=np.array([3,14,25,8])

plt.subplot(2,4,1)
plt.title("plot1")
plt.xlabel("xlab1")
plt.ylabel("ylab1")
plt.suptitle("supertitle") #not sub title

plt.plot(x,y)

#plot2
x=np.array([0,1,13,3])
y=np.array([3,14,25,8])

plt.subplot(2,4,2) #subplot(Row,column,plot number)
plt.title("plot2")
plt.xlabel("xlab2")
plt.ylabel("ylab2")
plt.plot(x,y)

#plot3
x=np.array([0,1,11,3])
y=np.array([3,14,25,8])

plt.subplot(2,4,3)
plt.title("plot3")
plt.plot(x,y)

#plot4
x=np.array([0,1,5,3])
y=np.array([3,14,25,8])

plt.subplot(2,4,4)
plt.title("plot4")
plt.plot(x,y)

#plot5
x=np.array([0,1,9,3])
y=np.array([3,14,25,8])

plt.subplot(2,4,5)
plt.title("plot5")
plt.plot(x,y)

#plot6
x=np.array([0,1,7,3])
y=np.array([3,14,25,8])

plt.subplot(2,4,6)
plt.title("plot6")
plt.plot(x,y)

#plot7
x=np.array([3,5,2,7])
y=np.array([3,14,25,8])

plt.subplot(2,4,7)
plt.title("plot7")
plt.plot(x,y)

#plot8
x=np.array([1,2,6,3])
y=np.array([3,14,25,8])

plt.subplot(2,4,8)
plt.title("plot8")
plt.plot(x,y)

plt.show()

# %%
### With pyplot we can use the scatter() function to draw a scatter plot.
## the scatter() function plots one dot for each observation. It needs two arrays of the same length,
## one for the values of the x axis and one for y axis.

x = np.array([5,4,5,6,6,7,7,8])
y = np.array([10,30,50,70,90,200,40,600])

plt.scatter(x,y)
plt.show()

# %%
x = np.array([5,4,5,6,6,7,7,8])
y = np.array([10,30,50,70,90,200,40,600])
sizes=np.array([99,11,233,222,333,444,555,666]) # length should be same for arrays
plt.scatter(x,y,s=sizes)
plt.show()

# %%
# you can adjust the transparency of the dots with Alpha arguement
x = np.array([5,4,5,6,6,7,7,8])
y = np.array([10,30,50,70,90,200,40,600])
sizes=np.array([99,11,233,222,333,444,555,666]) # length should be same for arrays
plt.scatter(x,y,s=sizes,alpha=0.1)
plt.show()

# %%
x = np.array(['A','B','C','D'])
y = np.array([10,30,50,70])
plt.bar(x,y)
plt.show()

# %%
x = np.array(['A','B','C','D'])
y = np.array([10,30,50,70])
plt.barh(x,y)
plt.show()

# %%
# Histogram
x=np.random.normal(170,10,250)

plt.hist(x)
plt.show()

# %%
y=np.array([35,25,25,15])

plt.pie(y)
plt.show()

# %%
y=np.array([35,25,25,15])
mylabels=["Apples","Bananas","Cherries","Dates"]
plt.pie(y,labels = mylabels,startangle = 90)
plt.show()

# %%
y=np.array([35,25,25,15])
mylabels=["Apples","Bananas","Cherries","Dates"]
myexplode = [0.1,0.3,0.1,0.1]
plt.pie(y,labels = mylabels,explode = myexplode)
plt.show()

# %%
y=np.array([35,25,25,15])
mylabels=["Apples","Bananas","Cherries","Dates"]
plt.pie(y,labels = mylabels)
plt.legend()
plt.show()
